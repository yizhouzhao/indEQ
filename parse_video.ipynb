# %%
import os
import cv2
from PIL import Image

# %%
memor_root = "/home/yizhou/Research/MEmor/MEmoR/data/"

# %%
memor_video_folder = os.path.join(memor_root, "videos")

# %%
memor_videos = sorted(os.listdir(memor_video_folder))

# %%
vidcap = cv2.VideoCapture(os.path.join(memor_video_folder, memor_videos[4]))

# %%
success,image = vidcap.read()

image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
pil_im = Image.fromarray(image)
pil_im
# Out:
# <PIL.Image.Image image mode=RGB size=720x480 at 0x7FD9F08D44D0>

# %%
frame_rate = vidcap.get(cv2.CAP_PROP_FPS)

# %%
vidcap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 384.0

# %%
frame_rate * 14.08
# Out:
# 337.58241758241763

# %%
vidcap.set(cv2.CAP_PROP_POS_FRAMES, frame_rate * 15)
# Out:
# True

# %%
success,image = vidcap.read()

image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
pil_im = Image.fromarray(image)
pil_im
# Out:
# <PIL.Image.Image image mode=RGB size=720x480 at 0x7FD9A407ED10>

# %%
pil_im.save("temp.jpg")

# %%
# import torch
# print(torch.__version__)
# print(torch.cuda.is_available())

# from demo import *

# setup_imports()

# #demo = MMFDemo()

# %%
from mmf.utils.env import setup_imports

# %%
setup_imports()

# %%
from parser.demo import MMFDemo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_39506/2379732071.py in <module>
# ----> 1 from parser.demo import MMFDemo
#
# ModuleNotFoundError: No module named 'parser.demo'; 'parser' is not a package

# %%
img_url = "./temp.jpg"
question = "How is the environment feeling?"

# %%
scores, predictions = demo.predict(img_url, question)

# %%
predictions
# Out:
# ['dark', 'warm', 'clear', 'calm', 'cool']

# %%
scores
# Out:
# [0.9999915361404419,
#  7.512778211093973e-06,
#  2.7496747634359053e-07,
#  2.7316323780723906e-07,
#  2.3831994155898428e-07]
